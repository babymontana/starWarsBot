# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import re

# %%
s = pd.read_csv("All-seasons.csv")[:1000]

# %%
s.head()
# Out:
#   Season Episode Character                                               Line
# 0     10       1      Stan         You guys, you guys! Chef is going away. \n
# 1     10       1      Kyle                        Going away? For how long?\n
# 2     10       1      Stan                                         Forever.\n
# 3     10       1      Chef                                  I'm sorry boys.\n
# 4     10       1      Stan  Chef said he's been bored, so he joining a gro...

# %%
for i in range(0,500):
    print("#",i+1)
    print(s.Line[i])
# Out:
# # 1
# You guys, you guys! Chef is going away.
#
# # 2
# Going away? For how long?
#
# # 3
# Forever.
#
# # 4
# I'm sorry boys.
#
# # 5
# Chef said he's been bored, so he joining a group called the Super Adventure Club.
#
# # 6
# Wow!
#
# # 7
# Chef?? What kind of questions do you think adventuring around the world is gonna answer?!
#
# # 8
# What's the meaning of life? Why are we here?
#
# # 9
# I hope you're making the right choice.
#
# # 10
# I'm gonna miss him.  I'm gonna miss Chef and I...and I don't know how to tell him!
#
# # 11
# Dude, how are we gonna go on? Chef was our fuh...f-ffriend.
#
# # 12
# And we will all miss you, Chef,  but we know you must do what your heart tells you..
#
# # 13
# Bye-bye!
#
# # 14
# Good-bye!
#
# # 15
# So long!
#
# # 16
# So long, Chef!
#
# # 17
# Good-bye, Chef!
#
# # 18
# Good-bye, Chef! Have a great time with the Super Adventure Club!
#
# # 19
# Good-bye! ..
#
# # 20
# Draw two card, fatass.
#
# # 21
# Reverse to you, Jew.
#
# # 22
# ...

# %%
# Para limpiar, no se reemplaza, se agrega un espacio en blanco
def limpia(texto):

    texto = texto.lower()
    
    texto = re.sub(r"\n", "",  texto)
    texto = re.sub(r"[-()]", "", texto)
    texto = re.sub(r"\.", ".", texto)
    texto = re.sub(r"\!", "!", texto)
    texto = re.sub(r"\?", "?", texto)
    texto = re.sub(r"\,", ",", texto)
    texto = re.sub(r"i'm", "i am", texto)
    texto = re.sub(r"he's", "he is", texto)
    texto = re.sub(r"she's", "she is", texto)
    texto = re.sub(r"it's", "it is", texto)
    texto = re.sub(r"that's", "that is", texto)
    texto = re.sub(r"what's", "that is", texto)
    texto = re.sub(r"\'ll", " will", texto)
    texto = re.sub(r"\'re", " are", texto)
    texto = re.sub(r"won't", "will not", texto)
    texto = re.sub(r"can't", "cannot", texto)
    texto = re.sub(r"n'", "ng", texto)
    texto = re.sub(r"ahh", "ah", texto)
    
    return texto

# %% [markdown]
# ### Procesamiento del archivo

# %%
# Carga el archivo
texto = []
for l in s.Line:
    texto.append(limpia(l))
texto
# Out:
# ['you guys, you guys! chef is going away. ',
#  'going away? for how long?',
#  'forever.',
#  'i am sorry boys.',
#  'chef said he is been bored, so he joining a group called the super adventure club. ',
#  'wow!',
#  'chef?? what kind of questions do you think adventuring around the world is gonna answer?!',
#  'that is the meaning of life? why are we here?',
#  'i hope you are making the right choice.',
#  'i am gonna miss him.  i am gonna miss chef and i...and i dongt know how to tell him! ',
#  'dude, how are we gonna go on? chef was our fuh...fffriend. ',
#  'and we will all miss you, chef,  but we know you must do what your heart tells you..',
#  'byebye!',
#  'goodbye!',
#  'so long!',
#  'so long, chef!',
#  'goodbye, chef!',
#  'goodbye, chef! have a great time with the super adventure club!',
#  'goodbye! ..',
#  'draw two card, fatass.',
#  'reverse to you, jew. ',
#  'i will get it. ',
#  'hello there, children!',
#  'he is back!',
#  'yeah!',
#  'all right! ',
# ...

# %%
# delimitar el largo máximo de cada línea
linea_extension = 50

texto_corto = []
for l in texto:
    print(l)
    if len(l.split()) <= linea_extension:
        texto_corto.append(l)
texto_corto
# Out:
# you guys, you guys! chef is going away.
# going away? for how long?
# forever.
# i am sorry boys.
# chef said he is been bored, so he joining a group called the super adventure club.
# wow!
# chef?? what kind of questions do you think adventuring around the world is gonna answer?!
# that is the meaning of life? why are we here?
# i hope you are making the right choice.
# i am gonna miss him.  i am gonna miss chef and i...and i dongt know how to tell him!
# dude, how are we gonna go on? chef was our fuh...fffriend.
# and we will all miss you, chef,  but we know you must do what your heart tells you..
# byebye!
# goodbye!
# so long!
# so long, chef!
# goodbye, chef!
# goodbye, chef! have a great time with the super adventure club!
# goodbye! ..
# draw two card, fatass.
# reverse to you, jew.
# i will get it.
# hello there, children!
# he is back!
# yeah!
# all right!
# chef! i cannot believe you are back!
# well, it is true.
# but are you back for good?
# that is right.
# ...

# %%
# Repeticiones por palabra
vocabulario = {}
for l in texto_corto:
    for palabra in l.split():
        if palabra not in vocabulario:
            vocabulario[palabra] = 1
        else:
            vocabulario[palabra] += 1
vocabulario
# Out:
# {'you': 317,
#  'guys,': 14,
#  'guys!': 3,
#  'chef': 15,
#  'is': 244,
#  'going': 28,
#  'away.': 5,
#  'away?': 1,
#  'for': 51,
#  'how': 29,
#  'long?': 1,
#  'forever.': 2,
#  'i': 266,
#  'am': 76,
#  'sorry': 4,
#  'boys.': 3,
#  'said': 3,
#  'he': 55,
#  'been': 12,
#  'bored,': 1,
#  'so': 37,
#  'joining': 1,
#  'a': 168,
#  'group': 2,
#  'called': 2,
#  'the': 343,
#  'super': 14,
#  'adventure': 14,
#  'club.': 5,
#  'wow!': 2,
#  'chef??': 1,
#  'what': 65,
#  'kind': 2,
#  'of': 126,
#  'questions': 3,
#  'do': 64,
#  'think': 27,
#  'adventuring': 1,
#  'around': 9,
#  'world': 4,
#  'gonna': 33,
#  'answer?!': 1,
#  'that': 141,
#  'meaning': 1,
#  'life?': 1,
#  'why': 16,
#  'are': 113,
#  'we': 130,
#  'here?': 5,
#  'hope': 3,
#  'making': 3,
#  'right': 18,
#  'choice.': 3,
#  'miss': 4,
#  'him.': 4,
#  'and': 102,
#  'i...and': 1,
#  'dongt': 51,
#  'know': 22,
#  'to': 255,
#  'tell': 7,
#  'him!': 3,
#  'dude,': 13,
#  'go': 26,
#  'on?': 2,
# ...

# %%
# Palabras con más de 3 veces
lm = 3
contador = 0
for k,v in vocabulario.items():
    if v >= lm:
        contador += 1

# %%
print("Total:", len(vocabulario))
print("Usar:",contador)
# Out:
# Total: 2484
# Usar: 566

# %%
# Vocabulario fuente a entero
vocabulario_fuente_int = {}

suma = 0
for k,v in vocabulario.items():
    if v >= lm:
        vocabulario_fuente_int[k] = suma
        suma += 1  
vocabulario_fuente_int
# Out:
# {'"family': 548,
#  '"first': 556,
#  "'family": 487,
#  '2': 511,
#  'a': 17,
#  'about': 155,
#  'acceptance': 443,
#  'actually': 410,
#  'adventure': 20,
#  'afraid': 259,
#  'after': 158,
#  'again,': 482,
#  'again.': 144,
#  'ah!': 326,
#  'ah,': 219,
#  'air': 472,
#  'air!': 432,
#  'air.': 531,
#  'airs': 529,
#  'all': 52,
#  'all.': 324,
#  'already': 453,
#  'alzawahri': 486,
#  'am': 10,
#  'american': 473,
#  'an': 327,
#  'and': 41,
#  'and...': 464,
#  'another': 110,
#  'any': 176,
#  'anymore.': 337,
#  'anything': 376,
#  'anyway,': 349,
#  'appear': 537,
#  'are': 32,
#  'are.': 414,
#  'arengt': 383,
#  'around': 27,
#  'as': 282,
#  'ask': 173,
#  'asking': 195,
#  'at': 354,
#  'aw,': 270,
#  'away.': 6,
#  'back': 79,
#  'back!': 72,
#  'bad': 499,
#  'bad?': 498,
#  'balls': 168,
#  'balls.': 289,
#  'be': 224,
#  'because': 241,
#  'become': 288,
#  'been': 15,
#  'before': 200,
#  'being': 291,
#  'believe': 76,
#  'best': 379,
#  'better': 267,
# ...

# %%
#Vocabulario objetivo... de qué quieres que hable el bot
vocabulario_objetivo_int = {}

suma = 0
for k,v in vocabulario.items():
    if v >= lm:
        vocabulario_objetivo_int[k] = suma
        suma += 1
vocabulario_objetivo_int
# Out:
# {'"family': 548,
#  '"first': 556,
#  "'family": 487,
#  '2': 511,
#  'a': 17,
#  'about': 155,
#  'acceptance': 443,
#  'actually': 410,
#  'adventure': 20,
#  'afraid': 259,
#  'after': 158,
#  'again,': 482,
#  'again.': 144,
#  'ah!': 326,
#  'ah,': 219,
#  'air': 472,
#  'air!': 432,
#  'air.': 531,
#  'airs': 529,
#  'all': 52,
#  'all.': 324,
#  'already': 453,
#  'alzawahri': 486,
#  'am': 10,
#  'american': 473,
#  'an': 327,
#  'and': 41,
#  'and...': 464,
#  'another': 110,
#  'any': 176,
#  'anymore.': 337,
#  'anything': 376,
#  'anyway,': 349,
#  'appear': 537,
#  'are': 32,
#  'are.': 414,
#  'arengt': 383,
#  'around': 27,
#  'as': 282,
#  'ask': 173,
#  'asking': 195,
#  'at': 354,
#  'aw,': 270,
#  'away.': 6,
#  'back': 79,
#  'back!': 72,
#  'bad': 499,
#  'bad?': 498,
#  'balls': 168,
#  'balls.': 289,
#  'be': 224,
#  'because': 241,
#  'become': 288,
#  'been': 15,
#  'before': 200,
#  'being': 291,
#  'believe': 76,
#  'best': 379,
#  'better': 267,
# ...

# %%
#Códigos únicos a los diccionarios
codigos_unicos = ['<PAD>','<EOS>','<UNK>','<GO>']

for c in codigos_unicos:
    vocabulario_fuente_int[c] = len(vocabulario_fuente_int)+1
vocabulario_fuente_int
# Out:
# {'"family': 548,
#  '"first': 556,
#  "'family": 487,
#  '2': 511,
#  '<EOS>': 568,
#  '<GO>': 570,
#  '<PAD>': 567,
#  '<UNK>': 569,
#  'a': 17,
#  'about': 155,
#  'acceptance': 443,
#  'actually': 410,
#  'adventure': 20,
#  'afraid': 259,
#  'after': 158,
#  'again,': 482,
#  'again.': 144,
#  'ah!': 326,
#  'ah,': 219,
#  'air': 472,
#  'air!': 432,
#  'air.': 531,
#  'airs': 529,
#  'all': 52,
#  'all.': 324,
#  'already': 453,
#  'alzawahri': 486,
#  'am': 10,
#  'american': 473,
#  'an': 327,
#  'and': 41,
#  'and...': 464,
#  'another': 110,
#  'any': 176,
#  'anymore.': 337,
#  'anything': 376,
#  'anyway,': 349,
#  'appear': 537,
#  'are': 32,
#  'are.': 414,
#  'arengt': 383,
#  'around': 27,
#  'as': 282,
#  'ask': 173,
#  'asking': 195,
#  'at': 354,
#  'aw,': 270,
#  'away.': 6,
#  'back': 79,
#  'back!': 72,
#  'bad': 499,
#  'bad?': 498,
#  'balls': 168,
#  'balls.': 289,
#  'be': 224,
#  'because': 241,
#  'become': 288,
#  'been': 15,
#  'before': 200,
# ...

# %%
for c in codigos_unicos:
    vocabulario_objetivo_int[c] = len(vocabulario_objetivo_int)+1
vocabulario_objetivo_int
# Out:
# {'"family': 548,
#  '"first': 556,
#  "'family": 487,
#  '2': 511,
#  '<EOS>': 568,
#  '<GO>': 570,
#  '<PAD>': 567,
#  '<UNK>': 569,
#  'a': 17,
#  'about': 155,
#  'acceptance': 443,
#  'actually': 410,
#  'adventure': 20,
#  'afraid': 259,
#  'after': 158,
#  'again,': 482,
#  'again.': 144,
#  'ah!': 326,
#  'ah,': 219,
#  'air': 472,
#  'air!': 432,
#  'air.': 531,
#  'airs': 529,
#  'all': 52,
#  'all.': 324,
#  'already': 453,
#  'alzawahri': 486,
#  'am': 10,
#  'american': 473,
#  'an': 327,
#  'and': 41,
#  'and...': 464,
#  'another': 110,
#  'any': 176,
#  'anymore.': 337,
#  'anything': 376,
#  'anyway,': 349,
#  'appear': 537,
#  'are': 32,
#  'are.': 414,
#  'arengt': 383,
#  'around': 27,
#  'as': 282,
#  'ask': 173,
#  'asking': 195,
#  'at': 354,
#  'aw,': 270,
#  'away.': 6,
#  'back': 79,
#  'back!': 72,
#  'bad': 499,
#  'bad?': 498,
#  'balls': 168,
#  'balls.': 289,
#  'be': 224,
#  'because': 241,
#  'become': 288,
#  'been': 15,
#  'before': 200,
# ...

# %%
vfuente_int_diccionario = {indice: v for v, indice in vocabulario_fuente_int.items()}
vfuente_int_diccionario
# Out:
# {0: 'you',
#  1: 'guys,',
#  2: 'guys!',
#  3: 'chef',
#  4: 'is',
#  5: 'going',
#  6: 'away.',
#  7: 'for',
#  8: 'how',
#  9: 'i',
#  10: 'am',
#  11: 'sorry',
#  12: 'boys.',
#  13: 'said',
#  14: 'he',
#  15: 'been',
#  16: 'so',
#  17: 'a',
#  18: 'the',
#  19: 'super',
#  20: 'adventure',
#  21: 'club.',
#  22: 'what',
#  23: 'of',
#  24: 'questions',
#  25: 'do',
#  26: 'think',
#  27: 'around',
#  28: 'world',
#  29: 'gonna',
#  30: 'that',
#  31: 'why',
#  32: 'are',
#  33: 'we',
#  34: 'here?',
#  35: 'hope',
#  36: 'making',
#  37: 'right',
#  38: 'choice.',
#  39: 'miss',
#  40: 'him.',
#  41: 'and',
#  42: 'dongt',
#  43: 'know',
#  44: 'to',
#  45: 'tell',
#  46: 'him!',
#  47: 'dude,',
#  48: 'go',
#  49: 'was',
#  50: 'our',
#  51: 'will',
#  52: 'all',
#  53: 'you,',
#  54: 'chef,',
#  55: 'but',
#  56: 'must',
#  57: 'your',
#  58: 'long,',
#  59: 'chef!',
#  60: 'have',
#  61: 'great',
#  62: 'time',
#  63: 'with',
#  64: 'club!',
#  65: 'two',
#  66: 'jew.',
# ...

# %%
vobjetivo_int_diccionario = {indice: v for v, indice in vocabulario_objetivo_int.items()}
vobjetivo_int_diccionario
# Out:
# {0: 'you',
#  1: 'guys,',
#  2: 'guys!',
#  3: 'chef',
#  4: 'is',
#  5: 'going',
#  6: 'away.',
#  7: 'for',
#  8: 'how',
#  9: 'i',
#  10: 'am',
#  11: 'sorry',
#  12: 'boys.',
#  13: 'said',
#  14: 'he',
#  15: 'been',
#  16: 'so',
#  17: 'a',
#  18: 'the',
#  19: 'super',
#  20: 'adventure',
#  21: 'club.',
#  22: 'what',
#  23: 'of',
#  24: 'questions',
#  25: 'do',
#  26: 'think',
#  27: 'around',
#  28: 'world',
#  29: 'gonna',
#  30: 'that',
#  31: 'why',
#  32: 'are',
#  33: 'we',
#  34: 'here?',
#  35: 'hope',
#  36: 'making',
#  37: 'right',
#  38: 'choice.',
#  39: 'miss',
#  40: 'him.',
#  41: 'and',
#  42: 'dongt',
#  43: 'know',
#  44: 'to',
#  45: 'tell',
#  46: 'him!',
#  47: 'dude,',
#  48: 'go',
#  49: 'was',
#  50: 'our',
#  51: 'will',
#  52: 'all',
#  53: 'you,',
#  54: 'chef,',
#  55: 'but',
#  56: 'must',
#  57: 'your',
#  58: 'long,',
#  59: 'chef!',
#  60: 'have',
#  61: 'great',
#  62: 'time',
#  63: 'with',
#  64: 'club!',
#  65: 'two',
#  66: 'jew.',
# ...

# %%
texto_fuente = texto_corto[:-1]
texto_fuente
# Out:
# ['you guys, you guys! chef is going away. ',
#  'going away? for how long?',
#  'forever.',
#  'i am sorry boys.',
#  'chef said he is been bored, so he joining a group called the super adventure club. ',
#  'wow!',
#  'chef?? what kind of questions do you think adventuring around the world is gonna answer?!',
#  'that is the meaning of life? why are we here?',
#  'i hope you are making the right choice.',
#  'i am gonna miss him.  i am gonna miss chef and i...and i dongt know how to tell him! ',
#  'dude, how are we gonna go on? chef was our fuh...fffriend. ',
#  'and we will all miss you, chef,  but we know you must do what your heart tells you..',
#  'byebye!',
#  'goodbye!',
#  'so long!',
#  'so long, chef!',
#  'goodbye, chef!',
#  'goodbye, chef! have a great time with the super adventure club!',
#  'goodbye! ..',
#  'draw two card, fatass.',
#  'reverse to you, jew. ',
#  'i will get it. ',
#  'hello there, children!',
#  'he is back!',
#  'yeah!',
#  'all right! ',
# ...

# %%
texto_objetivo = texto_corto[1:]

for i in range(len(texto_objetivo)):
    texto_objetivo[i] += ' <EOS>'
texto_objetivo
# Out:
# ['going away? for how long? <EOS>',
#  'forever. <EOS>',
#  'i am sorry boys. <EOS>',
#  'chef said he is been bored, so he joining a group called the super adventure club.  <EOS>',
#  'wow! <EOS>',
#  'chef?? what kind of questions do you think adventuring around the world is gonna answer?! <EOS>',
#  'that is the meaning of life? why are we here? <EOS>',
#  'i hope you are making the right choice. <EOS>',
#  'i am gonna miss him.  i am gonna miss chef and i...and i dongt know how to tell him!  <EOS>',
#  'dude, how are we gonna go on? chef was our fuh...fffriend.  <EOS>',
#  'and we will all miss you, chef,  but we know you must do what your heart tells you.. <EOS>',
#  'byebye! <EOS>',
#  'goodbye! <EOS>',
#  'so long! <EOS>',
#  'so long, chef! <EOS>',
#  'goodbye, chef! <EOS>',
#  'goodbye, chef! have a great time with the super adventure club! <EOS>',
#  'goodbye! .. <EOS>',
#  'draw two card, fatass. <EOS>',
#  'reverse to you, jew.  <EOS>',
#  'i will get it.  <EOS>',
# ...

# %%
#Convierte palabras a enteros
fuente_int = []
for l in texto_fuente:
    s = []
    for p in l.split():
        if p not in vocabulario_fuente_int:
            s.append(vocabulario_fuente_int['<UNK>'])
        else:
            s.append(vocabulario_fuente_int[p])
    fuente_int.append(s)
fuente_int
# Out:
# [[0, 1, 0, 2, 3, 4, 5, 6],
#  [5, 569, 7, 8, 569],
#  [569],
#  [9, 10, 11, 12],
#  [3, 13, 14, 4, 15, 569, 16, 14, 569, 17, 569, 569, 18, 19, 20, 21],
#  [569],
#  [569, 22, 569, 23, 24, 25, 0, 26, 569, 27, 18, 28, 4, 29, 569],
#  [30, 4, 18, 569, 23, 569, 31, 32, 33, 34],
#  [9, 35, 0, 32, 36, 18, 37, 38],
#  [9, 10, 29, 39, 40, 9, 10, 29, 39, 3, 41, 569, 9, 42, 43, 8, 44, 45, 46],
#  [47, 8, 32, 33, 29, 48, 569, 3, 49, 50, 569],
#  [41, 33, 51, 52, 39, 53, 54, 55, 33, 43, 0, 56, 25, 22, 57, 569, 569, 569],
#  [569],
#  [569],
#  [16, 569],
#  [16, 58, 59],
#  [569, 59],
#  [569, 59, 60, 17, 61, 62, 63, 18, 19, 20, 64],
#  [569, 569],
#  [569, 65, 569, 569],
#  [569, 44, 53, 66],
#  [9, 51, 67, 68],
#  [69, 70, 71],
#  [14, 4, 72],
#  [73],
#  [52, 74],
#  [59, 9, 75, 76, 0, 32, 72],
#  [77, 78, 4, 569],
#  [55, 32, 0, 79, 7, 569],
#  [30, 4, 80],
#  [81, 82, 83, 72],
#  [84, 52, 74, 73],
#  [85, 569],
#  [569,
#   78,
#   569,
#   86,
#   0,
#   87,
#   17,
#   61,
#   62,
# ...

# %%
objetivo_int = []
for l in texto_objetivo:
    s = []
    for p in l.split():
        
        if p not in vocabulario_objetivo_int:
            s.append(vocabulario_objetivo_int['<UNK>'])
        else:
            s.append(vocabulario_objetivo_int[p])
    objetivo_int.append(s)
objetivo_int
# Out:
# [[5, 569, 7, 8, 569, 568],
#  [569, 568],
#  [9, 10, 11, 12, 568],
#  [3, 13, 14, 4, 15, 569, 16, 14, 569, 17, 569, 569, 18, 19, 20, 21, 568],
#  [569, 568],
#  [569, 22, 569, 23, 24, 25, 0, 26, 569, 27, 18, 28, 4, 29, 569, 568],
#  [30, 4, 18, 569, 23, 569, 31, 32, 33, 34, 568],
#  [9, 35, 0, 32, 36, 18, 37, 38, 568],
#  [9, 10, 29, 39, 40, 9, 10, 29, 39, 3, 41, 569, 9, 42, 43, 8, 44, 45, 46, 568],
#  [47, 8, 32, 33, 29, 48, 569, 3, 49, 50, 569, 568],
#  [41,
#   33,
#   51,
#   52,
#   39,
#   53,
#   54,
#   55,
#   33,
#   43,
#   0,
#   56,
#   25,
#   22,
#   57,
#   569,
#   569,
#   569,
#   568],
#  [569, 568],
#  [569, 568],
#  [16, 569, 568],
#  [16, 58, 59, 568],
#  [569, 59, 568],
#  [569, 59, 60, 17, 61, 62, 63, 18, 19, 20, 64, 568],
#  [569, 569, 568],
#  [569, 65, 569, 569, 568],
#  [569, 44, 53, 66, 568],
#  [9, 51, 67, 68, 568],
#  [69, 70, 71, 568],
#  [14, 4, 72, 568],
#  [73, 568],
#  [52, 74, 568],
#  [59, 9, 75, 76, 0, 32, 72, 568],
#  [77, 78, 4, 569, 568],
# ...

# %% [markdown]
# ### Configuración del Modelo:

# %%
def datos_modelo():
    input_data = tf.placeholder(tf.int32, [None, None], name='input')
    targets = tf.placeholder(tf.int32, [None, None], name='targets')
    lr = tf.placeholder(tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    return input_data, targets, lr, keep_prob

# %%
def codificacion_input(target_data, vocab_to_int, batch_size):
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], vocab_to_int['<GO>']), ending], 1)
    return dec_input

# %%
#Creación el capa oculta
def codificacion_capa(rnn_inputs, rnn_size, num_layers, keep_prob, sequence_length, attn_length):
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    drop = tf.contrib.rnn.DropoutWrapper(lstm, input_keep_prob = keep_prob)
    cell = tf.contrib.rnn.AttentionCellWrapper(drop, attn_length, state_is_tuple = True)
    enc_cell = tf.contrib.rnn.MultiRNNCell([cell] * num_layers)
    _, enc_state = tf.nn.bidirectional_dynamic_rnn(cell_fw = enc_cell,
                                                   cell_bw = enc_cell,
                                                   sequence_length = sequence_length,
                                                   inputs = rnn_inputs, 
                                                   dtype=tf.float32)

    return enc_state

# %%
def decondificacion_capa_entrenamiento(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    train_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    train_pred, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(
        dec_cell, train_decoder_fn, dec_embed_input, sequence_length, scope=decoding_scope)
    train_pred_drop = tf.nn.dropout(train_pred, keep_prob)
    return output_fn(train_pred_drop)

# %%
def decodificacion_capa_inferencia(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    infer_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(
        output_fn, encoder_state, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size)
    infer_logits, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, infer_decoder_fn, scope=decoding_scope)
    return infer_logits

# %%
def decodificacion_capa(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, vocab_to_int, keep_prob, attn_length):    
    with tf.variable_scope("decoding") as decoding_scope:
        lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
        drop = tf.contrib.rnn.DropoutWrapper(lstm, input_keep_prob = keep_prob)
        cell = tf.contrib.rnn.AttentionCellWrapper(drop, attn_length, state_is_tuple = True)
        dec_cell = tf.contrib.rnn.MultiRNNCell([cell] * num_layers)
        
        weights = tf.truncated_normal_initializer(stddev = 0.1)
        biases = tf.zeros_initializer()
        output_fn = lambda x: tf.contrib.layers.fully_connected(x, 
                                                                vocab_size, 
                                                                None, 
                                                                scope=decoding_scope,
                                                                weights_initializer = weights,
                                                                biases_initializer = biases)

        train_logits = decondificacion_capa_entrenamiento(
            encoder_state[0], dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)
        decoding_scope.reuse_variables()
        infer_logits = decodificacion_capa_inferencia(encoder_state[0], dec_cell, dec_embeddings, vocab_to_int['<GO>'],
                                            vocab_to_int['<EOS>'], sequence_length, vocab_size,
                                            decoding_scope, output_fn, keep_prob)

    return train_logits, infer_logits

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, vocab_to_int, attn_length):
        
    enc_embed_input = tf.contrib.layers.embed_sequence(input_data, source_vocab_size+1, enc_embedding_size)
    enc_state = codificacion_capa(enc_embed_input, rnn_size, num_layers, keep_prob, sequence_length, attn_length)

    dec_input = codificacion_input(target_data, vocab_to_int, batch_size)
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size+1, dec_embedding_size], -1.0, 1.0))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)

    train_logits, infer_logits = decodificacion_capa(dec_embed_input, dec_embeddings, enc_state, target_vocab_size+1, 
                                                sequence_length, rnn_size, num_layers, vocab_to_int, keep_prob, 
                                                attn_length)
    
    return train_logits, infer_logits

# %%
### Hyper parámetros de la red
epochs = 10
batch_size = 128
rnn_size = 512
num_layers = 2
encoding_embedding_size = 512
decoding_embedding_size = 512
attn_length = 10
learning_rate = 0.0005
keep_probability = 0.8

# %%
#Configuración del grafo 
grafo = tf.Graph()
with grafo.as_default():
    
    # Carga datos del modelo
    input_data, targets, lr, keep_prob = datos_modelo()
    # Tamaño de la oración será el tamaño del batch
    sequence_length = tf.placeholder_with_default(lm, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    # Creación de las probabilidades del modelo
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(vocabulario_fuente_int), 
        len(vocabulario_objetivo_int), encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, 
        vocabulario_objetivo_int, attn_length)
    
    # Creación de los tensores
    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # función de pérdida
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizador
        optimizer = tf.train.AdamOptimizer(learning_rate)

        # Gradient Descend
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %%
def pad_sentence_batch(sentence_batch, vocab_to_int):
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [vocab_to_int['<PAD>']] * (max_sentence - len(sentence)) for sentence in sentence_batch]

# %%
def batch_data(source, target, batch_size):
    for batch_i in range(0, len(source)//batch_size):
        start_i = batch_i * batch_size
        source_batch = source[start_i:start_i + batch_size]
        target_batch = target[start_i:start_i + batch_size]
        yield (np.array(pad_sentence_batch(source_batch, vocabulario_fuente_int)), 
               np.array(pad_sentence_batch(target_batch, vocabulario_objetivo_int)))

# %%
entrenamiento_split = int(len(fuente_int)*0.1)

entrenamiento_fuente = fuente_int[entrenamiento_split:]
entrenamiento_objetivo = objetivo_int[entrenamiento_split:]

fuente_valido = fuente_int[:entrenamiento_split]
objetivo_valido = objetivo_int[:entrenamiento_split]

print(len(entrenamiento_fuente))
print(len(fuente_valido))
# Out:
# 877
# 97

# %% [markdown]
# # Ejecución del Modelo:

# %%
###Ejecución del entrenamiento
import time

learning_rate_decay = 0.95
display_step = 50
stop_early = 0
stop = 3
total_train_loss = 0
summary_valid_loss = []


checkpoint = "modelo.ckpt" 

with tf.Session(graph=grafo) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(1, epochs+1):
        for batch_i, (source_batch, target_batch) in enumerate(
                batch_data(entrenamiento_fuente, entrenamiento_objetivo, batch_size)):
            start_time = time.time()
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})

            total_train_loss += loss
            end_time = time.time()
            batch_time = end_time - start_time
            print(batch_i)
            if batch_i % display_step == 0:
                print('Epoca {:>3}/{} Batch {:>4}/{} - Perdida: {:>6.3f}, Segundos Procesamiento: {:>4.2f}'
                      .format(epoch_i,
                              epochs, 
                              batch_i, 
                              len(entrenamiento_fuente) // batch_size, 
                              total_train_loss / display_step, 
                              batch_time*display_step))
                total_train_loss = 0

            if batch_i % 235 == 0 and batch_i > 0:
                total_valid_loss = 0
                start_time = time.time()
                for batch_ii, (source_batch, target_batch) in \
                        enumerate(batch_data(fuente_valido, objetivo_valido, batch_size)):
                    valid_loss = sess.run(
                    cost, {input_data: source_batch,
                           targets: target_batch,
                           lr: learning_rate,
                           sequence_length: target_batch.shape[1],
                           keep_prob: 1})
                    total_valid_loss += valid_loss
                end_time = time.time()
                batch_time = end_time - start_time
                avg_valid_loss = total_valid_loss / (len(fuente_valido) / batch_size)
                print('Perdida Válida: {:>6.3f}, Segundos: {:>5.2f}'.format(avg_valid_loss, batch_time))
                
                learning_rate *= learning_rate_decay
                
                summary_valid_loss.append(avg_valid_loss)
                if avg_valid_loss <= min(summary_valid_loss):
                    print('Nuevo CheckPoint!') 
                    stop_early = 0
                    saver = tf.train.Saver() 
                    saver.save(sess, checkpoint)
                
                else:
                    print("Sin Mejora")
                    stop_early += 1
                    if stop_early == stop:
                        break
        if stop_early == stop:
            print("Termina entrenamiento.")
            break

# %% [markdown]
# # Ejecución del modelo:

# %%
def oracion_a_secuencia(sentence, vocab_to_int):
    sentence = limpia(sentence)
    return [vocab_to_int.get(word, vocab_to_int['<UNK>']) for word in sentence.split()]

# %%
input_sentence = 'Write here'


# Formato al input
input_sentence = oracion_a_secuencia(input_sentence, vocabulario_fuente_int)

checkpoint = "./" + checkpoint 

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Carga del grafo modelo
    loader = tf.train.import_meta_graph(checkpoint + '.meta')
    loader.restore(sess, checkpoint)
    # Carga de los tensores
    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
    # Ejecución del modelo    
    response_logits = sess.run(logits, {input_data: [input_sentence],keep_prob: 1.0})[0]

# Entrada del usuario
print('Entrada')
print('  Palabras entrada: {}'.format([vfuente_int_diccionario[i] for i in input_sentence]))

# Salida del Bot
print('\nRespuesta')
print('  Palabras del Bot: {}'.format([vobjetivo_int_diccionario[i] for i in np.argmax(response_logits, 1)]))
